# %%
import numpy as np
import pickle as pl

# %%
test_file = "training_data/test.pkl"
with open(test_file, "rb") as f:
    data = pl.load(f)

# %%
data['ICs'].shape
# Out:
# (12,)

# %%
data['Final_Data']
# Out:
# array([{'data': [<src.BlackHoles_Struct.BlackHole object at 0x7c235404dd50>, <src.BlackHoles_Struct.BlackHole object at 0x7c235404e310>, <src.BlackHoles_Struct.BlackHole object at 0x7c235404e7d0>, <src.BlackHoles_Struct.BlackHole object at 0x7c235404ec50>]},
#        {'data': [<src.BlackHoles_Struct.BlackHole object at 0x7c235404f250>, <src.BlackHoles_Struct.BlackHole object at 0x7c235404f810>, <src.BlackHoles_Struct.BlackHole object at 0x7c235404fcd0>]},
#        {'data': [<src.BlackHoles_Struct.BlackHole object at 0x7c2354054310>, <src.BlackHoles_Struct.BlackHole object at 0x7c23540548d0>, <src.BlackHoles_Struct.BlackHole object at 0x7c2354054d90>, <src.BlackHoles_Struct.BlackHole object at 0x7c2354055250>]},
#        {'data': [<src.BlackHoles_Struct.BlackHole object at 0x7c2354055810>, <src.BlackHoles_Struct.BlackHole object at 0x7c2354055dd0>, <src.BlackHoles_Struct.BlackHole object at 0x7c2354056290>]},
# ...
